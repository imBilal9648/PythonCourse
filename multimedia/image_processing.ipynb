# %%
from PIL import Image

# %%
im = Image.open('sample_small.jpeg')

# %%
im.show()

# %%
im.size # (width, height)
# Out:
# (290, 217)

# %%
w,h = im.size
print(f'resolution = {w} x {h} pixels')
# Out:
# resolution = 290 x 217 pixels

# %%
im.resize((100,200))
# Out:
# <PIL.Image.Image image mode=RGB size=100x200 at 0x2119B24F820>

# %%
im.resize((400,200))
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x2119B241FA0>

# %%
# scale to half size
im.resize((w//2,h//2))
# Out:
# <PIL.Image.Image image mode=RGB size=145x108 at 0x2119D8F9850>

# %%
# double the image size
im.resize((w*2,h*2))
# Out:
# <PIL.Image.Image image mode=RGB size=580x434 at 0x2119D910100>

# %%
# reduce image to 1/4 size
im.resize((w//4,h//4)).save('sample_small.jpeg')

# %%
from PIL import ImageFilter

# %%
sim = im.resize((w//4,h//4))
sim
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D910400>

# %%
sim.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D84A5E0>

# %%
sim.filter(ImageFilter.EDGE_ENHANCE)
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D8EADF0>

# %%
sim.filter(ImageFilter.EDGE_ENHANCE_MORE)
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D83CF70>

# %%
sim.filter(ImageFilter.BLUR)
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119B11A850>

# %%
sim.filter(ImageFilter.MaxFilter(3))
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D9105E0>

# %%
sim.filter(ImageFilter.MinFilter(3))
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D910460>

# %%
sim.filter(ImageFilter.GaussianBlur(25))
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119B131520>

# %%
sim.rotate(13)
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D910CA0>

# %%
sim.rotate(90,fillcolor='white')
# Out:
# <PIL.Image.Image image mode=RGB size=72x54 at 0x2119D8EABB0>

# %%
sim.rotate(90,expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=54x72 at 0x2119D84A190>

# %%
# blend 2 images together
im1 = Image.open('sample.jpeg')
im2 = Image.open('riot.png')
print(im1.size , im2.size)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\ASUS\OneDrive\Documents\PythonCourse\multimedia\image_processing.ipynb Cell 23' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000022?line=0'>1</a> # blend 2 images together
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000022?line=1'>2</a> im1 = Image.open('sample.jpeg')
#       <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000022?line=2'>3</a> im2 = Image.open('riot.png')
#       <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000022?line=3'>4</a> print(im1.size , im2.size)
#
# File c:\Users\ASUS\miniconda3\lib\site-packages\PIL\Image.py:2953, in open(fp, mode, formats)
#    2950     filename = fp
#    2952 if filename:
# -> 2953     fp = builtins.open(filename, "rb")
#    2954     exclusive_fp = True
#    2956 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.jpeg'

# %%
im2 = im2.resize(im1.size)
print(im1.size , im2.size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ASUS\OneDrive\Documents\PythonCourse\multimedia\image_processing.ipynb Cell 24' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000023?line=0'>1</a> im2 = im2.resize(im1.size)
#       <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000023?line=1'>2</a> print(im1.size , im2.size)
#
# NameError: name 'im2' is not defined

# %%
print(im1.mode, im2.mode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ASUS\OneDrive\Documents\PythonCourse\multimedia\image_processing.ipynb Cell 25' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000024?line=0'>1</a> print(im1.mode, im2.mode)
#
# NameError: name 'im1' is not defined

# %%
im2 = im2.convert('RGB')
print(im1.mode, im2.mode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ASUS\OneDrive\Documents\PythonCourse\multimedia\image_processing.ipynb Cell 26' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000025?line=0'>1</a> im2 = im2.convert('RGB')
#       <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000025?line=1'>2</a> print(im1.mode, im2.mode)
#
# NameError: name 'im2' is not defined

# %%
Image.blend(im1,im2,0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ASUS\OneDrive\Documents\PythonCourse\multimedia\image_processing.ipynb Cell 27' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive/Documents/PythonCourse/multimedia/image_processing.ipynb#ch0000026?line=0'>1</a> Image.blend(im1,im2,0.7)
#
# NameError: name 'im1' is not defined
